# %%
from pathlib import Path
home= Path("/home/getalp/lopezfab")

output_list = home / "Attention_git" / "marco_script" / "list_filename_matrice" / "concat" / "cutted_matrice_corrected" / "list_chemin.txt"

input_chemin = home / "Attention/concat/Process/post-processed_attn_corrected/5_output/src_side"

liste_file = [str(file) for file in input_chemin.iterdir()]
astr = "\n".join(liste_file)
with output_list.open("w") as f:
    f.write(astr)
# Out:
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_0_src_k0.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_1_src_k0.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_1_src_k1.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_2_src_k0.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_2_src_k1.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_2_src_k2.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_3_src_k0.tsv
# /home/getalp/lopezfab/Attention/concat/Process/post-processed_attn_corrected/5_output/src_side/src_3_src_k1.tsv
# ...

# %%
print(output_list)
