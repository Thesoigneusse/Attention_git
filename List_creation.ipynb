# %% [markdown]
# ## Script de création de liste à process

# %%
_concat = False

_OUTPUT_PATH = "/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice"
_MODEL = "concat" if _concat else "multi_enc"
_INPUT_PATH= f"/home/getalp/lopezfab/Documents/{_MODEL}"
_HEAD = 0
_LAYER = 0

# %%
print(os.path.join(_INPUT_PATH, "1850", str(0), str(0)))
# Out:
# /home/getalp/lopezfab/lig/Document/multi_enc/1850/0/0

# %%
import os

heads = [0, 186, 335, 457, 690, 792, 1034, 1268, 1420, 1610, 1755, 1782, 1814, 1863, 1910, 1932, 1958, 1989, 2009, 2044, 2075, 2108, 2123, 2153, 2191, 2214, 2245, 2262, 2280]


def lister_fichiers_pour_combinaisons(_id_min, _id_max):
    for nombre1 in range(8):
        for nombre2 in range(8):
            nom_fichier_sortie = f"{_OUTPUT_PATH}/list_chemin_{nombre1}_{nombre2}.txt"
            
            # Liste pour stocker les chemins de fichiers trouvés
            fichiers = []
            offset = 0
            # Parcours les dossiers {_id} de _id_min à _id_max
            for _id in range(_id_min, _id_max + 1):
                identifiant = _id + offset
                if _id not in heads and _id -1 not in heads:
                    # Construit le chemin du dossier cible
                    chemin_dossier = os.path.join(_INPUT_PATH, str(identifiant), str(nombre1)) #, str(nombre2))
                    
                    # Ajoute les fichiers trouvés à la liste principale
                    fichiers.append(f"{chemin_dossier}/{nombre2}.tsv")
                elif _id in heads:
                    offset += 1
            
            # Écrit les chemins des fichiers trouvés dans le fichier de sortie
            try:
                with open(nom_fichier_sortie, "w") as f_out:
                    for fichier in fichiers:
                        f_out.write(f"{fichier}\n")
                
                print(f"Fichier '{nom_fichier_sortie}' créé avec {len(fichiers)} fichiers.")
            
            except Exception as e:
                print(f"Erreur lors de l'écriture du fichier '{nom_fichier_sortie}': {e}")


_id_min = 1
_id_max = 2278

lister_fichiers_pour_combinaisons(_id_min, _id_max)
# Out:
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_0_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_1_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_2_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_3_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_4_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_5_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_6_7.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_0.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_1.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_2.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_3.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_4.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_5.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_6.txt' créé avec 2223 fichiers.
# Fichier '/home/getalp/lopezfab/Bureau/Attention_git/marco_script/list_filename_matrice/multi_enc/full_matrice/list_chemin_7_7.txt' créé avec 2223 fichiers.
