# %%
import xml.etree.ElementTree as ET

tree = ET.parse('Test.xml')
root = tree.getroot()

for markable in root:
    markable: ET.Element[str]
    print(markable.attrib['category'])
# Out:
# Action
# Thriller

# %%
from pathlib import Path
